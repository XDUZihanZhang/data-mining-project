# %% [markdown]
# # 1. Overview: LightGBM Modeling Workflow

# %% [markdown]
# # LightGBM Modeling Workflow Overview
#
# This notebook documents a full end-to-end pipeline for training, optimizing, and interpreting a LightGBM model to predict drinking behavior (`DRK_YN`) using health and demographic data.
#
# ---
#
# ## Workflow Steps:
#
# ### 1. Load Preprocessed Dataset
# We load cleaned training, validation, and test datasets (`X_train_lgb`, `X_val_lgb`, `X_test_lgb` and corresponding labels) from the preprocessed data directory.
#
# ### 2. Baseline Model Training
# We train a LightGBM model with default parameters to establish baseline performance. Model evaluation includes:
# - AUC, accuracy, precision, recall, F1-score
# - Confusion matrix and ROC curve
#
# ### 3. Feature Importance Analysis
# Using LightGBM’s built-in `feature_importances_`, we rank all features and visualize the top contributors with a bar plot. This informs us about which features drive model predictions.
#
# ### 4. Model Training with Selected Features
# We retrain LightGBM using only the top N most important features (e.g., 24). We compare this model’s performance with the baseline to determine whether feature selection improves generalization.
#
# ### 5. Hyperparameter Tuning with Optuna
# We apply Optuna to search for the best combination of hyperparameters by maximizing AUC on the validation set. Tuned parameters include:
# - `n_estimators`, `max_depth`, `learning_rate`
# - `subsample`, `colsample_bytree`, `reg_alpha`, `reg_lambda`
#
# ### 6. Final Model Training with Best Parameters
# We retrain LightGBM with the best parameters obtained from Optuna and evaluate the model on both validation and test sets.
#
# ### 7. Model Evaluation & Visualization
# A comparison table summarizes performance metrics across:
# - Baseline (validation)
# - Tuned model (validation and test)
#
# Performance is also visualized using grouped bar plots to highlight improvements.
#
# ### 8. Model Interpretation with SHAP
# We use SHAP to interpret feature contributions at both global and individual levels. Summary plots and bar charts provide transparency into model decision logic.
#
# ### 9. Save Final Model
# The final LightGBM model is saved as a `.pkl` file for deployment or reuse, following standard practice.

# %% [markdown]
# # 2. Load Processed Data

# %%
# 2. Load Preprocessed Data
from pathlib import Path
import pandas as pd

# Set base data directory
data_dir = Path("../data/processed")

# Load XGBoost datasets using relative paths
X_train_lgb = pd.read_csv(data_dir / "X_train_lgb.csv")
X_val_lgb = pd.read_csv(data_dir / "X_val_lgb.csv")
X_test_lgb = pd.read_csv(data_dir / "X_test_lgb.csv")

y_train_lgb = pd.read_csv(data_dir / "y_train_lgb.csv").squeeze()  # squeeze to convert to Series
y_val_lgb = pd.read_csv(data_dir / "y_val_lgb.csv").squeeze()
y_test_lgb = pd.read_csv(data_dir / "y_test_lgb.csv").squeeze()

# Confirm shapes
print("Training set:", X_train_lgb.shape, y_train_lgb.shape)
print("Validation set:", X_val_lgb.shape, y_val_lgb.shape)
print("Test set:", X_test_lgb.shape, y_test_lgb.shape)
# Out:
# Training set: (693942, 29) (693942,)
# Validation set: (148702, 29) (148702,)
# Test set: (148702, 29) (148702,)

# %% [markdown]
# # 3. Baseline LightGBM Model

# %%
from lightgbm import LGBMClassifier

# Initialize baseline LightGBM model with default parameters
lgb_model = LGBMClassifier(
    objective='binary',
    random_state=42,
    verbose=-1
)

# Fit model on training data
lgb_model.fit(X_train_lgb, y_train_lgb)

# Predict on validation and test sets
y_val_pred = lgb_model.predict(X_val_lgb)
y_val_proba = lgb_model.predict_proba(X_val_lgb)[:, 1]

y_test_pred = lgb_model.predict(X_test_lgb)
y_test_proba = lgb_model.predict_proba(X_test_lgb)[:, 1]

# %%
from sklearn.metrics import (
    roc_auc_score, accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report, roc_curve
)
import matplotlib.pyplot as plt
import seaborn as sns

# 4. Evaluation metrics
val_auc = roc_auc_score(y_val_lgb, y_val_proba)
val_acc = accuracy_score(y_val_lgb, y_val_pred)
val_precision = precision_score(y_val_lgb, y_val_pred)
val_recall = recall_score(y_val_lgb, y_val_pred)
val_f1 = f1_score(y_val_lgb, y_val_pred)
conf_mat = confusion_matrix(y_val_lgb, y_val_pred)

# 5. Print results
print("Validation Set Performance (Baseline LightGBM):")
print(f"AUC:        {val_auc:.4f}")
print(f"Accuracy:   {val_acc:.4f}")
print(f"Precision:  {val_precision:.4f}")
print(f"Recall:     {val_recall:.4f}")
print(f"F1 Score:   {val_f1:.4f}")
print("\nClassification Report:\n", classification_report(y_val_lgb, y_val_pred))

# 6. Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix - Validation Set")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()

# 7. Plot ROC curve
fpr, tpr, _ = roc_curve(y_val_lgb, y_val_proba)
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f"LightGBM (AUC = {val_auc:.4f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Validation Set")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Validation Set Performance (Baseline LightGBM):
# AUC:        0.8222
# Accuracy:   0.7395
# Precision:  0.7358
# Recall:     0.7471
# F1 Score:   0.7414
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74     74379
#            1       0.74      0.75      0.74     74323
#
#     accuracy                           0.74    148702
#    macro avg       0.74      0.74      0.74    148702
# weighted avg       0.74      0.74      0.74    148702

# %% [markdown]
# # 4. Feature Importance Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Get feature importances from the trained LightGBM model
importances = lgb_model.feature_importances_
feature_names = X_train_lgb.columns

# Create a DataFrame for easier plotting
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Select top N features to display
top_n = 10
top_features = importance_df.head(top_n)

# Plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(
    x='Importance', y='Feature',
    data=top_features,
    palette='Blues_d',
    edgecolor='black'
)

# Improve plot aesthetics
plt.title('Top 10 Feature Importances (LightGBM)', fontsize=14, weight='bold')
plt.xlabel('Importance Score', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/fh/_tq_jbr50895yx1hkbgpct5m0000gn/T/ipykernel_93044/2306304022.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # 5. Model Performance with Selected Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    roc_auc_score, accuracy_score, classification_report, 
    confusion_matrix, roc_curve
)
from lightgbm import LGBMClassifier

# 1. Select top features
selected_features = importance_df.head(22)['Feature'].tolist()
X_train_sel = X_train_lgb[selected_features]
X_val_sel = X_val_lgb[selected_features]
X_test_sel = X_test_lgb[selected_features]

# 2. Train model with selected features
selected_model = LGBMClassifier(
    objective='binary',
    random_state=42,
    verbose=-1
)
selected_model.fit(X_train_sel, y_train_lgb)

# 3. Predictions
y_val_proba = selected_model.predict_proba(X_val_sel)[:, 1]
y_val_pred = selected_model.predict(X_val_sel)
y_test_proba = selected_model.predict_proba(X_test_sel)[:, 1]
y_test_pred = selected_model.predict(X_test_sel)

# 4. Evaluation scores (Validation)
print("Validation Set Performance (Selected Features):")
print(f"AUC:      {roc_auc_score(y_val_lgb, y_val_proba):.4f}")
print(f"Accuracy: {accuracy_score(y_val_lgb, y_val_pred):.4f}")
print("Classification Report:\n", classification_report(y_val_lgb, y_val_pred))

# Confusion Matrix - Validation
cm_val = confusion_matrix(y_val_lgb, y_val_pred)
sns.heatmap(cm_val, annot=True, fmt="d", cmap="Blues", xticklabels=[0,1], yticklabels=[0,1])
plt.title("Validation Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()

# ROC Curve - Validation
fpr, tpr, _ = roc_curve(y_val_lgb, y_val_proba)
plt.plot(fpr, tpr, label='LightGBM (AUC = %.4f)' % roc_auc_score(y_val_lgb, y_val_proba))
plt.plot([0, 1], [0, 1], 'k--')
plt.title("Validation ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Validation Set Performance (Selected Features):
# AUC:      0.8221
# Accuracy: 0.7396
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74     74379
#            1       0.74      0.75      0.74     74323
#
#     accuracy                           0.74    148702
#    macro avg       0.74      0.74      0.74    148702
# weighted avg       0.74      0.74      0.74    148702

# %% [markdown]
# # 6. Hyperparameter Tuning with Optuna

# %%
import optuna
from optuna.visualization import plot_optimization_history, plot_param_importances
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

# 1. Define Optuna objective function
def objective(trial):
    params = {
        'objective': 'binary',
        'random_state': 42,
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0)
    }

    model = LGBMClassifier(**params)
    model.fit(X_train_lgb, y_train_lgb)

    val_pred_proba = model.predict_proba(X_val_lgb)[:, 1]
    auc = roc_auc_score(y_val_lgb, val_pred_proba)
    return auc

# 2. Create study and run optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)

# 3. Display best result
print("Best trial:")
print(f"AUC: {study.best_value:.4f}")
print("Best parameters:", study.best_params)
# Out:
# [I 2025-05-05 10:31:16,949] A new study created in memory with name: no-name-bdf0cebb-4117-4367-9ee8-ed2dfaba3d7a
# [I 2025-05-05 10:31:20,866] Trial 0 finished with value: 0.8210478705267911 and parameters: {'n_estimators': 279, 'max_depth': 9, 'learning_rate': 0.29013644804160854, 'subsample': 0.5156879096357719, 'colsample_bytree': 0.7159510320573726, 'reg_alpha': 0.895499126841583, 'reg_lambda': 0.8518930507185015}. Best is trial 0 with value: 0.8210478705267911.
# [I 2025-05-05 10:31:30,493] Trial 1 finished with value: 0.8195432487740686 and parameters: {'n_estimators': 366, 'max_depth': 11, 'learning_rate': 0.012809996170083616, 'subsample': 0.8029133014206332, 'colsample_bytree': 0.7533129913606309, 'reg_alpha': 0.3950456641192822, 'reg_lambda': 0.8951046338618711}. Best is trial 0 with value: 0.8210478705267911.
# ...

# %% [markdown]
# # 7. Final Model Training with Best Parameters

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import (
    accuracy_score, roc_auc_score, classification_report, 
    confusion_matrix, roc_curve
)
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Retrieve best parameters from Optuna
best_params = study.best_params
best_params.update({
    'objective': 'binary',
    'random_state': 42
})

# 2. Retrain model using best parameters
final_model = LGBMClassifier(**best_params)
final_model.fit(X_train_lgb, y_train_lgb)

# 3. Predictions on validation and test sets
y_val_proba = final_model.predict_proba(X_val_lgb)[:, 1]
y_val_pred = final_model.predict(X_val_lgb)

y_test_proba = final_model.predict_proba(X_test_lgb)[:, 1]
y_test_pred = final_model.predict(X_test_lgb)

# 4. Evaluation on validation set
print("Validation Set Performance (Tuned LightGBM):")
print(f"AUC:      {roc_auc_score(y_val_lgb, y_val_proba):.4f}")
print(f"Accuracy: {accuracy_score(y_val_lgb, y_val_pred):.4f}")
print("Classification Report:\n", classification_report(y_val_lgb, y_val_pred))

# Confusion Matrix - Validation
cm_val = confusion_matrix(y_val_lgb, y_val_pred)
sns.heatmap(cm_val, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
plt.title("Confusion Matrix - Validation Set (Tuned LightGBM)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# ROC Curve - Validation
fpr, tpr, _ = roc_curve(y_val_lgb, y_val_proba)
plt.plot(fpr, tpr, label=f"AUC = {roc_auc_score(y_val_lgb, y_val_proba):.4f}")
plt.plot([0, 1], [0, 1], 'k--')
plt.title("ROC Curve - Validation Set")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Validation Set Performance (Tuned LightGBM):
# AUC:      0.8233
# Accuracy: 0.7404
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74     74379
#            1       0.74      0.75      0.74     74323
#
#     accuracy                           0.74    148702
#    macro avg       0.74      0.74      0.74    148702
# weighted avg       0.74      0.74      0.74    148702

# %% [markdown]
# # 8. Model Evaluation and Visualization

# %%
import pandas as pd
from sklearn.metrics import (
    roc_auc_score, accuracy_score, precision_score,
    recall_score, f1_score
)

# Build comparison DataFrame using consistent model references
comparison_df = pd.DataFrame({
    'Metric': ['AUC', 'Accuracy', 'Precision', 'Recall', 'F1 Score'],
    
    'Baseline (Val)': [
        roc_auc_score(y_val_lgb, lgb_model.predict_proba(X_val_lgb)[:, 1]),
        accuracy_score(y_val_lgb, lgb_model.predict(X_val_lgb)),
        precision_score(y_val_lgb, lgb_model.predict(X_val_lgb)),
        recall_score(y_val_lgb, lgb_model.predict(X_val_lgb)),
        f1_score(y_val_lgb, lgb_model.predict(X_val_lgb))
    ],
    
    'Tuned (Val)': [
        roc_auc_score(y_val_lgb, y_val_proba),
        accuracy_score(y_val_lgb, y_val_pred),
        precision_score(y_val_lgb, y_val_pred),
        recall_score(y_val_lgb, y_val_pred),
        f1_score(y_val_lgb, y_val_pred)
    ],
    
    'Tuned (Test)': [
        roc_auc_score(y_test_lgb, y_test_proba),
        accuracy_score(y_test_lgb, y_test_pred),
        precision_score(y_test_lgb, y_test_pred),
        recall_score(y_test_lgb, y_test_pred),
        f1_score(y_test_lgb, y_test_pred)
    ]
})

# Round for better display
comparison_df.iloc[:, 1:] = comparison_df.iloc[:, 1:].round(4)

# Display the table
print(comparison_df)
# Out:
#       Metric  Baseline (Val)  Tuned (Val)  Tuned (Test)
# 0        AUC          0.8222       0.8233        0.8250
# 1   Accuracy          0.7395       0.7404        0.7421
# 2  Precision          0.7358       0.7370        0.7407
# 3     Recall          0.7471       0.7472        0.7447
# 4   F1 Score          0.7414       0.7421        0.7427

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for clarity
sns.set_style("whitegrid")

# Plot bar chart
ax = comparison_df.set_index('Metric').plot(
    kind='bar',
    figsize=(10, 6),
    width=0.6,
    colormap='tab20c',
    edgecolor='black'
)

# Add value labels to each bar
for container in ax.containers:
    ax.bar_label(container, fmt='%.3f', label_type='edge', fontsize=9)

# Adjust y-axis to highlight differences (change if needed)
plt.ylim(0.70, 0.88)  # Adjust based on actual model scores
plt.title("Model Performance Comparison (Baseline vs Tuned)", fontsize=14, weight='bold')
plt.ylabel("Score", fontsize=12)
plt.xlabel("Metric", fontsize=12)
plt.xticks(rotation=0, fontsize=11)
plt.yticks(fontsize=11)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend(title="Model", loc='upper right', fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. SHAP Model Interpretation

# %%
# !pip install shap
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 546.9/546.9 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 16.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import shap

# 1. Create SHAP explainer from trained LightGBM model
explainer = shap.TreeExplainer(final_model)

# 2. Compute SHAP values on validation set
shap_values = explainer.shap_values(X_val_lgb)

# 3. Summary plot (global explanation)
shap.summary_plot(shap_values, X_val_lgb)

# 4. Bar plot (mean absolute SHAP values per feature)
shap.summary_plot(shap_values, X_val_lgb, plot_type='bar')
# Out:
# /opt/homebrew/anaconda3/envs/pytorch/lib/python3.12/site-packages/shap/explainers/_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(

# %% [markdown]
# ### SHAP Summary Plot Analysis (LightGBM)
#
# The SHAP summary plot for the **LightGBM model** shows a similar set of top predictors, but with some unique structural differences:
#
# - **Top Features**:
#   - `age`, `SMK_stat_type_cd`, `gamma_GTP`, and `sex_Male` appear again as the dominant features.
#   - Other features like `HDL_chole`, `AST_ALT_ratio`, and `SGOT_ALT` also contribute meaningfully.
#
# - **Observed Gaps & Step-like Patterns**:
#   - Some features exhibit visible gaps or banded SHAP distributions.
#   - This is due to **LightGBM's histogram-based tree construction**, where continuous features are binned into discrete intervals, resulting in grouped SHAP values.
#   - It also reflects hard threshold splits (e.g., age > 55), typical of tree-based models.
#
# - **Interpretability**:
#   - Despite these discontinuities, the direction of influence is still interpretable:
#     - Higher `gamma_GTP` and `age` values generally increase the likelihood of drinking.
#     - Categorical features like `SMK_stat_type_cd` show strong, discrete influence.
#
# These patterns highlight LightGBM's efficient but aggressive thresholding behavior, which captures sharp transitions in prediction logic.(non-drinker).

# %% [markdown]
# # 10. Save Model and Parameters
